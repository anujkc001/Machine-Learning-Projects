# %%
# import pandas as pd 
# import yfinance as yf
# import datetime
# from datetime import date,timedelta
# today=date.today()

# d1=today.strftime("%Y-%m-%d")
# end_date=d1
# d2=date.today() - timedelta(days=730)
# d2=d2.strftime("%Y-%m-%d")
# start_date=d2

# data=yf.download('BTC-USD',
#                 start=start_date,
#                 end=end_date,
#                  process=False)

# data["Date"]=data.index
# data=data[["Date","Open","High","Low","Close"," Adj Close","Volume"]]
# data.reset_index(drop=True,inplace=True)
# print(data.head())

# import yfinance as yf

# # Fix: Change 'process' to 'progress'
# data = yf.download('BTC-USD', 
#                   start=start_date, 
#                   end=end_date, 
#                   progress=False)

# data["Date"] = data.index
# # Note: Ensure "Adj Close" does not have a leading space unless the library adds it
# data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]

import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=730)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 52
#      47 data = yf.download('BTC-USD',
#      48                       start=start_date,
#      49                       end=end_date,
#      50                       progress=False)
#      51 data["Date"] = data.index
# ---> 52 data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
#      53 data.reset_index(drop=True, inplace=True)
#      54 print(data.head())
#
# File ~\miniconda3\envs\codexenv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\envs\codexenv\Lib\site-packages\pandas\core\indexes\multi.py:2782, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2779 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2780     indexer = self._get_indexer_level_0(keyarr)
# -> 2782     self._raise_if_missing(key, indexer, axis_name)
#    2783     return self[indexer], indexer
#    2785 return super()._get_indexer_strict(key, axis_name)
#
# File ~\miniconda3\envs\codexenv\Lib\site-packages\pandas\core\indexes\multi.py:2800, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2798 cmask = check == -1
#    2799 if cmask.any():
# -> 2800     raise KeyError(f"{keyarr[cmask]} not in index")
#    2801 # We get here when levels still contain values which are not
#    2802 # actually in Index anymore
#    2803 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['Adj Close'] not in index"
