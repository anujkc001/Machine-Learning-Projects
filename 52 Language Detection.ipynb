# %%
! pip install langdetect
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ---------- ----------------------------- 262.1/981.5 kB ? eta -:--:--
#      ------------------- ---------------- 524.3/981.5 kB 553.1 kB/s eta 0:00:01
#      --------------------------------------- 981.5/981.5 kB 939.5 kB/s  0:00:01
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993363 sha256=2cd0c3d3e3502697809fe6cc5c9483428de78e6c70b06c9761945b247568a00a
#   Stored in directory: c:\users\chauh\appdata\local\pip\cache\wheels\eb\87\25\2dddf1c94e1786054e25022ec5530bfed52bad86d882999c48
# Successfully built langdetect
# ...

# %%
from langdetect import detect
text = input("Enter any text in any language: ")
print(detect(text))
# Out:
# Enter any text in any language:  愛してます
# ja
