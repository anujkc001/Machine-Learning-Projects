# %%
from pytube import YouTube

# %%
link="https://www.youtube.com/watch?v=1tiHpkRbWf8&list=RD1tiHpkRbWf8&start_radio=1"
yt=YouTube(link,use_oauth=True, allow_oauth_cache=True)

# %%
# To print title
print("Title :", yt.title)

# To get number of views
print("Views :", yt.views)

# To get the length of Video 
print("Duration :", yt.length)

# To get description
print("Description :", yt.description)

# To get ratings
print("Ratings :", yt.rating)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # To print title
# ----> 2 print("Title :", yt.title)
#       4 # To get number of views
#       5 print("Views :", yt.views)
#
# File ~\miniconda3\envs\codexenv\Lib\site-packages\pytube\__main__.py:341, in YouTube.title(self)
#     338     return self._title
#     340 try:
# --> 341     self._title = self.vid_info['videoDetails']['title']
#     342 except KeyError:
#     343     # Check_availability will raise the correct exception in most cases
#     344     #  if it doesn't, ask for a report.
#     345     self.check_availability()
#
# File ~\miniconda3\envs\codexenv\Lib\site-packages\pytube\__main__.py:246, in YouTube.vid_info(self)
#     242     return self._vid_info
#     244 innertube = InnerTube(use_oauth=self.use_oauth, allow_cache=self.allow_oauth_cache)
# ...

# %%
# !pip install yt-dlp
# Out:
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.4/3.3 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.1/3.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 3.6 MB/s  0:00:00
# ...

# %%
import yt_dlp

url = 'https://www.youtube.com/watch?v=Vd7F5VHz5BI&list=RDVd7F5VHz5BI&start_radio=1&rv=KlfNQqJbCJQ'

# Options to just extract info without downloading
ydl_opts = {}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(url, download=False)
    
    print(f"Title : {info.get('title')}")
    print(f"Views : {info.get('view_count')}")
    print(f"Uploader: {info.get('uploader')}")
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=Vd7F5VHz5BI&list=RDVd7F5VHz5BI&start_radio=1&rv=KlfNQqJbCJQ
# [youtube:tab] Downloading playlist RDVd7F5VHz5BI - add --no-playlist to download just the video Vd7F5VHz5BI
# [youtube:tab] RDVd7F5VHz5BI: Downloading webpage
# [download] Downloading playlist: Mix - ALL NIGHT (LIVE) - AP DHILLON | SHINDA KAHLON (Official Music Video)
# [youtube:tab] RDVd7F5VHz5BI page 1: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 2: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 3: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 4: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 5: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 6: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 7: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 8: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 9: Downloading API JSON
# [youtube:tab] RDVd7F5VHz5BI page 10: Downloading API JSON
# ...
